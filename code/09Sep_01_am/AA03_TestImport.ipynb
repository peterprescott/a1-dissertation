# %%
from go import n
# Out:
# Initializing database connection...
# Database connected!
# Getting data took 0 minutes, 0 seconds.

# %%
from nbhd.geometry import cellularize

# %%
n.cells = cellularize(n.uprn.geometry, n.geom)

# %%
n.cells
# Out:
#                                                geometry
# 0     POLYGON Z ((338074.010 393629.490 0.000, 33809...
# 1     POLYGON Z ((338091.616 393655.749 0.000, 33809...
# 2     POLYGON Z ((338092.898 393657.661 0.000, 33809...
# 3     POLYGON Z ((338093.320 393658.291 0.000, 33809...
# 4     POLYGON Z ((338096.232 393662.634 0.000, 33809...
# ...                                                 ...
# 3341  POLYGON Z ((338249.102 392662.030 0.000, 33826...
# 3342  POLYGON Z ((338478.762 393260.432 0.000, 33850...
# 3343  POLYGON Z ((338252.298 392471.468 0.000, 33825...
# 3344  POLYGON Z ((338249.545 392455.636 0.000, 33824...
# 3345  POLYGON Z ((338261.233 392451.650 0.000, 33825...
#
# [3346 rows x 1 columns]

# %%
n.cells.plot()
# Out:
# <AxesSubplot:>
