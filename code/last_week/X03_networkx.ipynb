# %%
import networkx as nx

# %%
G = nx.Graph()

# %%
G.add_node(1)

# %%
G.add_nodes_from([2,3])

# %%
G

# %%
G.add_nodes_from(
[(4, {'color':'green'}), (5, {'color':'red'})])

# %%
H= nx.path_graph(10)

# %%
G

# %%
H

# %%
G.add_nodes_from(H)

# %%
# edges

# %%
G.add_edge(1,2)

# %%
e = (2,3)

# %%
G.add_edge(*e)

# %%
list(G.nodes)
# Out:
# [1, 2, 3, 4, 5, 0, 6, 7, 8, 9]

# %%
list(G.edges)
# Out:
# [(1, 2), (2, 3)]

# %%
G.degree(2)
# Out:
# 2

# %%
p = nx.petersen_graph()

# %%
p.edges
# Out:
# EdgeView([(0, 1), (0, 4), (0, 5), (1, 2), (1, 6), (2, 3), (2, 7), (3, 4), (3, 8), (4, 9), (5, 7), (5, 8), (6, 8), (6, 9), (7, 9)])

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(p)

# %%
dd = nx.dodecahedral_graph()
nx.draw(dd)

# %%
list(nx.connected_components(G))
# Out:
# [{1, 2, 3}, {4}, {5}, {0}, {6}, {7}, {8}, {9}]
