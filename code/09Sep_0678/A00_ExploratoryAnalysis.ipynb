# %%
import sys
sys.path.append('..')

# %%
from nbhd import data

# %%
db = data.Base()
# Out:
# Initializing database connection...
# Database connected!

# %%
tables = db.ls()

# %%
cols = db.info(tables[0]).Column

# %%
from IPython.display import display

# %%
for t in tables[1:]:
    print(t)
    display(db.info(t))
# Out:
# nodes
#            Column               Datatype
# 0              id                   text
# 1  formOfRoadNode                   text
# 2        geometry  geometry(Point,27700)
# buildings
#         Column                 Datatype
# 0           id                     text
# 1  featureCode                   bigint
# 2     geometry  geometry(Polygon,27700)
# roads
#                       Column                    Datatype
# 0                         id                        text
# 1                    endNode                        text
# 2                  startNode                        text
# 3             roadNumberTOID                        text
# 4               roadNameTOID                        text
# 5                 fictitious                     boolean
# 6         roadClassification                        text
# 7              road_function                        text
# 8                  formOfWay                        text
# ...

# %%
# find numbers, medians, interquartile ranges
