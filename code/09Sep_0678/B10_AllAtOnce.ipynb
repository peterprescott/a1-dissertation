# %%
import sys

# %%
sys.path.append('..')

# %%
from nbhd import data

# %%
db = data.Base()
# Out:
# Initializing database connection...
# Database connected!

# %%
from shapely.geometry import Point

# %%
from shapely.geometry import MultiPolygon

# %%
import matplotlib.pyplot as plt

# %%
from nbhd import geometry

# %%
from nbhd.geometry import trim

# %%
import geopandas as gpd

# %%
from nbhd.geography import square_plot

# %%
ax, gdfs = square_plot(338300, 392120, 100, db)

# %%
gdfs[0].road_function.unique()
# Out:
# array(['Local Road'], dtype=object)
